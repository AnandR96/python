# %% [markdown]
# <a href="https://colab.research.google.com/github/AnandR96/python_basic/blob/main/Copy_of_Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
d1=pd.read_csv('/content/drive/MyDrive/Copy of college_1.csv')
d2=pd.read_csv('/content/drive/MyDrive/Copy of college_2.csv')
df=pd.concat([d1,d2],axis=0)
df
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
unsatisfactory=df.loc[(df['CodeKata Score']<7000)]
unsatisfactory.to_csv('Unsatisfactory.csv')

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df['average_score']= (df['Previous Geekions']+df['CodeKata Score'])/2

# %% [markdown]
# ###### No of students participated

# %%
df['Name'].value_counts().sum()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df['average_comp_python_mysql'] = (df['python']+df['mysql']+df['python_en']+df['computational_thinking'])/4

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_stars=df.sort_values(by=['CodeKata Score'],ascending=False)
rising_stars.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        NaN
# 1  Computer Science and Engineering       0        NaN
# 2  Computer Science and Engineering       0        NaN
#
#    computational_thinking  average_score  average_comp_python_mysql
# 0                     NaN        24500.0                        NaN
# 1                     NaN        21740.0                        NaN
# 2                     NaN        19680.0                        NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
shining_stars=df.sort_values(by=['Previous Geekions'],ascending=False)
shining_stars.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        NaN
# 1  Computer Science and Engineering       0        NaN
# 2  Computer Science and Engineering       0        NaN
#
#    computational_thinking  average_score  average_comp_python_mysql
# 0                     NaN        24500.0                        NaN
# 1                     NaN        21740.0                        NaN
# 2                     NaN        19680.0                        NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
eedeptwise = df.loc[(df['Department']=='Electronics and Electrical Engineering')]
eedeptwise.sort_values(['CodeKata Score'],ascending=False)
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0     ASHOK KUMAR K   100.0   31.0              19400           19400
# 4         VIINU V P    -1.0   24.0               9150            9150
# 8          shifak N    58.0    0.0               5180            8320
# 9           Balaji     -1.0   20.0               6170            8160
# 12         JPradhap   100.0    0.0               7340            8030
# 64       k.parvathi   100.0  100.0                260             260
# 71      m.keerthana    97.5    0.0                120             120
# 72       Subhashini   100.0    4.0                120             120
# 74  J.Bhuvaneshwari   100.0   20.0                100             100
# 75         santhosh    82.0   12.0                 60              60
# 78     vikneshwaran   100.0    4.0                 40              40
# 77       J.JAYANTHI   100.0  100.0                 40              40
# ...

# %%
edeptwise = df.loc[(df['Department']=='Electronics and Communication Engineering')]
edeptwise['CodeKata Score'].sum()
edeptwise.sort_values(['CodeKata Score'],ascending=False)
# Out:
#                           Name  python   mysql  Previous Geekions  \
# 3              Bodipudi Harini    -1.0   35.00              10040
# 7                    Gowtham R    -1.0    4.00               8650
# 6                KALAIARASAN K    85.0   47.00               7750
# 14                   Praneetha    -1.0  100.00               7170
# 16                     Guhan S    -1.0   35.00               7310
# 8                   J.SUGANTHI    27.0   50.00               5860
# 10             Iyappan Samiraj    50.0   24.00               5400
# 24               P.GOVARDHANAN    -1.0    0.00               5050
# 14             Melvin Dukles.R    56.0   20.00               4800
# 17                 v.vithyasri   100.0   12.00               4370
# 18          Abirami Anbazhagan   100.0    0.00               4320
# 21                kamalishwari    32.0   20.00               3665
# 29                   Abishak s    -1.0   35.00               3220
# ...

# %%
cdeptwise = df.loc[(df['Department']=='Computer Science and Engineering')]
cdeptwise['CodeKata Score'].sum()
cdeptwise.sort_values(['CodeKata Score'],ascending=False)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           A.Dharani    82.0   20.0              24500           24500
# 1         V.JEEVITHA     82.0   20.0              21740           21740
# 2         HEMAVATHI.R   100.0  100.0              19680           19680
# 1             Chandru     0.0    0.0              14150           14490
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# ..                ...     ...    ...                ...             ...
# 66     Evanasundari.K    61.0    0.0                180             180
# 69         karthika.G   100.0    0.0                120             120
# 76               Arun    95.0    4.0                 40              40
# 33               XY Z    -1.0   -1.0                  0               0
# 34          Hariharan    -1.0   -1.0                  0               0
#
#                           Department  Rising  python_en  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = [53800,108335,320025]
labels = ['Computer Science and Engineering','Electronics and Communication Engineering','Electronics and Electrical Engineering']
colors = sns.color_palette('bright')
plt.pie(data, labels=labels,colors = colors, autopct = '%0.0f%%')
plt.show()

# %%
df['Department'].unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
import pandas as pd
dfo = pd.DataFrame({'Department': ['Computer Science and Engineering', 'Electronics and Communication Engineering', 'Electronics and Electrical Engineering'],
                   'toppers': [24500, 10040, 19400]})
dfo.plot.barh(x='Department', y='toppers',
             title='Department wise toppers', color='yellow')
